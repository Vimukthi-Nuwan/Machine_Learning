# %% [markdown]
# <a href="https://colab.research.google.com/github/Vimukthi-Nuwan/Regression/blob/main/random_forest_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('Position_Salaries.csv')
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 42)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %% [markdown]
# ## Predicting a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([180000.])

# %% [markdown]
# ## Visualising the Random Forest Regression results (higher resolution)

# %%
x_grid = np.arange(X.min(), X.max(), 0.01)
x_grid = x_grid.reshape(len(x_grid), 1)
plt.scatter(X, y, color = 'green')
plt.plot(x_grid, regressor.predict(x_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
